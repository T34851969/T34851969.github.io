# %% [markdown]
# # 生活习惯与睡眠质量关联分析

# %% [markdown]
# ## 导入依赖

# %%
import numpy as np
import pandas as pd
import matplotlib
import seaborn as sb

# %%
# 读取数据
df = pd.read_csv('sleep_data.csv')

# 基础数据检查
print(df.info())
print(df.describe())
print(df.isnull().sum())  # 检查缺失值
